# %%
from tensorflow import keras
print('keras: ', keras.__version__)
# Out:
# keras:  2.8.0

# %% [markdown]
# ## Implementing character-level LSTM text generation
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the English language.

# %% [markdown]
# ### 1.1 Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 1us/step
# 614400/600901 [==============================] - 0s 1us/step
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ### 1.2 Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
from tensorflow.keras import optimizers

optimizer = optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# ### 1.3 Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature # take a log function and then divided by temperature
    exp_preds = np.exp(preds) # take a exp function
    preds = exp_preds / np.sum(exp_preds) # normalize to 1
    probas = np.random.multinomial(1, preds, 1) # roll a dice based on the probability distribution in preds
    return np.argmax(probas) #return to the selected "next character"

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text_initial = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text_initial + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        generated_text = generated_text_initial
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 282s 179ms/step - loss: 1.9625
# --- Generating with seed: "ore unjust. the vice of the judgment
# consists, first, in the"
# ------ temperature: 0.2
# ore unjust. the vice of the judgment
# consists, first, in the something the self-and and the stronger and the dod the something the perhaps and the reasion of the some and all the may and a still the standand and the some all the some the stronger and the science and the feeling the such and the fore the some and the religion and the some the such and the such a man a most and all the finess and all the mast destray and the something to the reasons and all
# ------ temperature: 0.5
# ore unjust. the vice of the judgment
# consists, first, in the
# lature as the state prefeness of the formony and emolious of laves and have one the believess of the may and have not therespention and the adtion in the eachings and all the sciences of the sometained the some to the strances and the batad dispection and to the existing to the most consequences and the recional with the lade to the the bolonged and the religen and
# the essention the contination t
# ------ temperature: 1.0
# ore unjust. the vice of the judgment
# consists, first, in the edeture procesnisy itkols a zostience, that is such weo tuxistantity, a becation to the folmament under here
# sdafied to the uaysous wirdin of philosophess that which and or dis evened decraest all thetsion
# europsthings in a thought of puined is
# regllation the non anta. because
# a theed at other no philosorefain of very
# knowad oud
#  "have vee to peareneds of deless of
# such freaves.
#
#
# kd nither not a
# ------ temperature: 1.2
# ore unjust. the vice of the judgment
# consists, first, in the
# smaztionly rel the unistation the wullis incuptbrifoment philosopead, werlhing" this pow: in they worderishs a god eatenty -tuknerad ass, at the woild thad e, almaykatusm or
# these distrant to does reaucnens, towarned and or
# eesove gunalf sucie about them and impirmali, are ast: itserry owedinkally
# and fore in a
# penherds, akongly
# very tajured yew
# kneelokfuli, rejuct an attself's-fearhallome and wh
# epoch 2
# 1565/1565 [==============================] - 277s 177ms/step - loss: 1.6116
# --- Generating with seed: "done with a
# strict regard for others. rather do others affor"
# ------ temperature: 0.2
# done with a
# strict regard for others. rather do others afford of the same to the distingues and and the promet to the promined and all the daring to a moral and and and in the same to the same the same and the same the dangerous and and all the conscience of the conscience of the same to the morality of the conscience of the same and to the south of the same the same to the same south of the same to the same the depression of the same the conscience of the
# ------ temperature: 0.5
# done with a
# strict regard for others. rather do others affor and at or because the great loge is ammoral to at the moral of the dution of the powers of the same have to the depress of the
#  the exerrance of will the south at the signification of secret of to and ageness and insels in the and to the south of such and account of the conscience and souls of like to a action in the world the are in the conscience of the conscience of the conscience of the depre
# ------ temperature: 1.0
# done with a
# strict regard for others. rather do others affor musich life opluse of succersped (or would belide conscience, to will these fine to daifine, lover sucho, dispresuses to knowe, which everth spiration, braue, the dases
#  sermine of sensess ack an goodsical wom; to before stard to it noy so lacerfully, a morally, cbectity estally a courses ors, have origalise man immerd to indrend holoss for tradment--as from humany--in religed: it usind. provoni
# ------ temperature: 1.2
# done with a
# strict regard for others. rather do others afford; thingle
# coudk; to sko's best pare of man tn rgage, which obywart lead peremagion wither badfait son south fain lavous
# could adeang anjothemy and baindrouts.
# its ons domles differspapty, with, hew sulf viebolit as and kin-leade
# andswabse his alwardanspress. consuqut
# ksy; to consider--ase to but
# con
# cucuosmon wounded, alworl betpacely outwapperary.
#
#
# rigiv. b? evingutient in the lherl, and secret
# epoch 3
# 1565/1565 [==============================] - 279s 178ms/step - loss: 1.5268
# --- Generating with seed: "ther hand, for scientific discoveries like those of darwin, "
# ------ temperature: 0.2
# ther hand, for scientific discoveries like those of darwin, and and and in the contempting that is not the contempt and the contempt the sense of the sensible and more of the superitance of the moral of the contemptance of the destrusted the men would be the sensible in the counterity of the man and self-conception of the same the best on the sensible of the counterity of the contempt of the course of the cause of the moral contempt to one of the sensible
# ------ temperature: 0.5
# ther hand, for scientific discoveries like those of darwin, that the soul, which the man and becumition.
#
#
# 1
#
#
# =at entary in the spirit of the words every he know the man the earther of his sensibli. in the same and the man, and in the one of the existes of the can necessary of the develtation. the be of the manical of induces and sensible, the enjoyment and with the world of the desire of the cause indication of the such an under the great in find and in
# ------ temperature: 1.0
# ther hand, for scientific discoveries like those of darwin, inteccisity-in the require strictified and reneful, and can refereit, but
# the kinning
# in an, night to be selies bit will "yoursger of found regards blinds
# at prisies been whes to an indecence and alword shy the s far the priising-ideas. of seleistly, arr tible, perhaps, instinctophere firctity perhaps laverisms from them superiocs that he of the lofi, the distrupsuation would viecate coult with tr
# ------ temperature: 1.2
# ther hand, for scientific discoveries like those of darwin, seemsupwacturecinacuons
# concuutly must of fundament1ific for soldunation,
# with short in him who by dloivy, a funct
# gationthing:--day be caristait be veriorition of dosy,
# heter tays, what
# in interpoursed to seaking that is evol, again, words for,
# he greating in one my free powerful unyed unknows digcurative reason, i mishaw a mry nocy, shords," to onvise--schopenian result? juance has anssence,
# he
# epoch 4
# 1565/1565 [==============================] - 278s 178ms/step - loss: 1.4801
# --- Generating with seed: "--to do away with suffering; and we?--it really seems that w"
# ------ temperature: 0.2
# --to do away with suffering; and we?--it really seems that with a states and sense of the specially and the specially and all the sense of the profoundly the sense of the sense of the sense of the same are a species to all the sense of the fact the state of the sense of the sense of the sense of the speciality of the protections and sense of the sense of the specially to allow and considered to the prosent the proposition of the domine to the prosent the s
# ------ temperature: 0.5
# --to do away with suffering; and we?--it really seems that which as the devilized have
# been the greater and lived of the happeralism of such the last and necessary of the can the new divine to the man is not that with extroding to the state of the catem of an exterding it state and a metaphysical person the greater the bad the believes probation for everything distrustfuritation is it of the sense for the present perhaps and person that and no doction of t
# ------ temperature: 1.0
# --to do away with suffering; and we?--it really seems that wsoteving the a? fait. every german necessary. we of did smale does that it sickligied forms streve to be a beload tomayies, "the dijoldisns, no lisok protesness. "dispissibiss--what sperious-we cause become men,
# the justice curite and abome of belief with it. he wholly respect to refore,
# plission, of a once altomes: selfss and exensis ofey absologe stephal get of one of suit
# to believe in the dive
# ------ temperature: 1.2
# --to do away with suffering; and we?--it really seems that which lonechable buths convidecation sycuptionity convince to very kovwes thats forward of once disperateces it procerty liyexie
# f"liber of this faitentive advicting lj?atthers and some
# speats in occasionsy age to  gulf to bal new, sun, it is
# be power-hanises, this boline "super their dxuct. there is from
# himself how
# leidg lofus under-beptimes also form, thorlies conslariousness of "irrisous. man
# o
# epoch 5
# 1565/1565 [==============================] - 280s 179ms/step - loss: 1.4506
# --- Generating with seed: ", from sunless conceptual-spectrism and from poverty of
# bloo"
# ------ temperature: 0.2
# , from sunless conceptual-spectrism and from poverty of
# blood and are the same such a standard and sense in the soul is also the sense of a moral and conditions of the command the same the commening the present and present and all the soul is an and soul has been and some the same are the compoles and and to a soul of the same experience of the same the complesed the present in the strength the present and the present and the most spirit of the same the di
# ------ temperature: 0.5
# , from sunless conceptual-spectrism and from poverty of
# blood of the soul-and and shortifulness and a commenced the respections, the convitions in the slaver to the sign the ends of the first comes the more as exceptally in the estimate and command history, more developed and also and strength the nature of no longer what something conception of such a man is in the come because in the hard a nations and man present according to one's person of the dimardi
# ------ temperature: 1.0
# , from sunless conceptual-spectrism and from poverty of
# blood, for the been at
# and likele pits of an ambialry of allieves the dulligu is to at enaliral defectated, lark are "belwereally, inthat so
# happens which which hesilard which all do such a longertance of the floots if,
# "bling other
# ascounds, rapeae rank
# envuits: heself, put has now has its solexs in conditionable patopale evil
# learnes.
#
# 139. afrains ablented, that into
# : there is world by reamile sol
# ------ temperature: 1.2
# , from sunless conceptual-spectrism and from poverty of
# bloodonce and operiti sy, that cauquesverentnes, well oughen enven "gres de, a diugftes is soul. at one
# aqualmet meatory man by such the
# idea valfici" blowner undinxiturable nack anitally exchall, sharm multina's, id; that it in
# rilatedingsion, to kposis such a equality;" we caseling slan, which camably from , highal o-thisself" and avolati mises we nivinity etical elsemable sufferried the
# worker toma
# epoch 6
# 1565/1565 [==============================] - 278s 178ms/step - loss: 1.4274
# --- Generating with seed: "ess educates
# and prepares for "unbelief" more than anything "
# ------ temperature: 0.2
# ess educates
# and prepares for "unbelief" more than anything which the distrustful is the distrustful is the distrustful of the super-the subtersistence of the spirit of the senses of the distrustful is not the super-the same the distrustful is the greatest to the same all the destruction of the most destruction of the sufferint to the senses of the same a profound and distrustful is not believe the profound to the fact a man and all the spirit of the super
# ------ temperature: 0.5
# ess educates
# and prepares for "unbelief" more than anything advantain to the one no longer a praise and distrustful, and physionging to my and the world of the floblings, and become in liberty believe as the mast and say, as the sphing to be encient sensibility become the greatest that the should be does not who better, perhaps a reasons of the dispined and self-doternism who long the conscience, such a soul, taste of his profess of the invaluation of the
# ------ temperature: 1.0
# ess educates
# and prepares for "unbelief" more than anything plassible, lifeest and be fundamental ancerity: he should
# ceems. worn and i"
# within
# the germany physiongering are been best preecialus and persith have a really he paintic to one cere man more, whether
# all delight himself to can streached by the view pride,--with oneserventic, our intervit and so
# more lishing for
# but that himself to the adminn to the s-reasoned: for mens of
# their interpretitude in
# ------ temperature: 1.2
# ess educates
# and prepares for "unbelief" more than anything as
# act gratly situatofating--"pures, lain lith xiferitof, persanness free feter light complumence
#
# nmytenabslom, rofuly does
# a sups a. one does nom beding birst preo, fruedes that we meanoughly
# o) "nature, it
# ispremited to all them"d feter
# sensibility sieglizer for of the conduct
# for the unaqual thonest of
# makes! bairsly aurestily knowledgg, and in
# this idpaint things, a; hereavordam, wourd
# geepsr
# epoch 7
# 1565/1565 [==============================] - 279s 178ms/step - loss: 1.4122
# --- Generating with seed: "er of the world.
# indeed no cruel man is ever as cruel, in th"
# ------ temperature: 0.2
# er of the world.
# indeed no cruel man is ever as cruel, in the sense of the sense of the sense of the sense of the sense of the presuning the sense of the present man in the morality of the sense of the sense of the sense of the present man in the sense of the sense of the sense of the means of the sense of the will to the sense of the sense of the sense of the sense of the present man in the sense of the sense of the sense of the sense of the sense of the
# ------ temperature: 0.5
# er of the world.
# indeed no cruel man is ever as cruel, in the sense of the good even to him we artistous and prefort in an in the sense of the sense of the sense of the sense of the
# distinct the enture he in the taste of the more and sense of the spirit and different man will one has he others and soul of the present soul of the distingunt to the philosophers and great there is a people the a good of the sense of the reality and there is a good. the most i
# ------ temperature: 1.0
# er of the world.
# indeed no cruel man is ever as cruel, in the
# suffer the oldind of a guart conscious for tempert one just man
# and philosopher," tow, and which he man" as ensioldes of guide with times than itself, eshage.
#
#            that). one can no denceals with vivloud in whee inclinatoud to prropess--whetho ording, and love something the good (when the effect have tentement withqutices, of these diffilious flavalive and elivaryis (in respected bothing
# ------ temperature: 1.2
# er of the world.
# indeed no cruel man is ever as cruel, in then last developeds. they ditince--" that do
# mentualed false "uthust--this phe-saking in
# spherness and likes "workour that angmalisms--firet. "he make coal of mind, oicaulm, for the lont and dis any bast "weivesmed for transdang") in souls artrans him liturous, in the relationly sens. at last bandrxing
# more false"
# through thethorise, to needs plexa awtbeing in soonuous to thei. sford aintimmalr? he
# epoch 8
# 1565/1565 [==============================] - 279s 178ms/step - loss: 1.3963
# --- Generating with seed: "ection and ultimate maturity in every
# culture and art, the e"
# ------ temperature: 0.2
# ection and ultimate maturity in every
# culture and art, the existic and the soul of the more something that which as a men in the sentiment of the man and something from the sentiments of the spirit of the sense of the seems and self-desires of the self-desires of which a more proved to the soul of the free spirits of the sentiments of the sentiment of the merital of the more present and in the sentiment in the more soul, and which is an and strong and and
# ------ temperature: 0.5
# ection and ultimate maturity in every
# culture and art, the existic and there is an and by an and was
# in the laws little as a soul of the more religions correspent and with there is and in the demand which is sensional self-fast and distinguous, in conception of fear is no longer will to the opposed of the man and really the world of desire the continue and self-moral and superiorical signification man so nature, the present so are souls and with the german
# ------ temperature: 1.0
# ection and ultimate maturity in every
# culture and art, the european and command--ho
# will
# impression, who supendency as impleed (thoougg sortse. the way will, and into me everything from che for a b'est persaace:
# like to has to delicate degroe of happinted, consists is in this pain, i gruatient the most and circhment to picious, and regreem as concess-limate
# resuption must propreased of ind fgrcuman pewherly, and  whoever and fromboi, pertath or"ce, consinc
# ------ temperature: 1.2
# ection and ultimate maturity in every
# culture and art, the exocise, has poor lear, congeing-wackorly sprieved and the writing should as itsilation, the illurties! perioderis,
# and force
# of moraled", type, ifoquane heness elson, arr a matecon of hy should his would that which exist herebained; sensual l. metaphysical idab:         nothcoudor, the respolrity--and itself
# deed toolpaten--were with the ethiring tywow like irewe boft" new seem the historying. a m
# epoch 9
# 1565/1565 [==============================] - 280s 179ms/step - loss: 1.3858
# --- Generating with seed: "and
# modern philosophers with regard to tragedy--may no longe"
# ------ temperature: 0.2
# and
# modern philosophers with regard to tragedy--may no longer conceive the sentiment of the sentiment the same such a present opinion of the sentiment in the same the master of the conscience of the moral the moral the moral in the sentiment of the sentiment the conscience of the same self-responsibility to the soul of the distingus and the conceive the sentiment of the soul of the moral and the moral of the sentiment of the conscience of the sentiment of
# ------ temperature: 0.5
# and
# modern philosophers with regard to tragedy--may no longer the mind more ears in solitude and the things between the comparisted and this fundamentally perhaps man of the power, the strength of woman--and of the god, short, and present disposed to the sentiment to present circumspect of the moral and adderly in the respect, the senses and or
# also
# spoll conceive moral experience of the religious of purpose it was life a former present distinguishes itsel
# ------ temperature: 1.0
# and
# modern philosophers with regard to tragedy--may no longer cases, ratilants and which where this sust
# beenkyd--a best distinge entaral
# age would beof
# wondiur, doctardian of it severity of
# themselves at every ement, and has auwhists
# and exuaction of (a some thoughts in lows, "does--all hyself of itself--that wentomes.
#
#
# 1rtaver with
# all the philosophy because
# less this gent
# nue but bepolitfer neiterny, happincism itself, wy hafferentwiths-and vowitism, e
# ------ temperature: 1.2
# and
# modern philosophers with regard to tragedy--may no longer as why no dection
# milusts gramitally such comperencs,
# the
# reader.wk--the lofes live philosophies ont onefoled dangerous
# simgled
# the closs: it
# maste," and has [minue with the germanigats, beasking; the c.ditants anaptrianly all the
# whole"
# sdarg,
# with final penolie, thuses in,
# and to--have only. at present may
# shor of condition: hownch fyheain, retroft; this awadems senters to savery plival of wor
# epoch 10
# 1565/1565 [==============================] - 280s 179ms/step - loss: 1.3755
# --- Generating with seed: " the relationship to the
# olympian gods, it becomes possible "
# ------ temperature: 0.2
#  the relationship to the
# olympian gods, it becomes possible to the sense of the sense of the sense of the sentiment of the precisely the present from the present the present has a more the present and secural and the present the serves of the present and the present of the present the most precisely the present in the sense of the fatter of the master of the man and the sense of the master of the fact the present the present and consequently the self the p
# ------ temperature: 0.5
#  the relationship to the
# olympian gods, it becomes possible to the constant the presence of the value, and its have being the constant he would not perhaps the word of the compared to the bad intellectuality, which knows and the precisely be a beautic), and and him with a hurarity of the sentiment of the bad has a matter of the conscience of the hardable be predication and counce, and assigner,
# and cause of the world in the seriousness and superficially an
# ------ temperature: 1.0
#  the relationship to the
# olympian gods, it becomes possible -be to language--in order to the ;ancient some right of intensirord-than the
# phingmarity the penparasience of merely impulse the mosticlaclesical
# invision of freem of dational feely, he is , his perhame with them communing leclging
# apprepicilisely one most goe internal acrome developed the uncomgrence upon
# many
# synthating friendliness some womonity law into proproteint has comprependating precisel
# ------ temperature: 1.2
#  the relationship to the
# olympian gods, it becomes possible and light--and individuality and use personalities has, a leative of arranger" space should can necessary,
# he
# words them must any
# good "opinion. in artlented. out
# of things ungresing.
#
#
# rayfaquence of virtue,
# his bedavens "writies.
#
#
#
#
#
# i onavlighten now time .ay day like with home consisisfict of true, hitherto the  the achially a
# misundudfved culituafed, anywne reflace, which when their develope
# epoch 11
# 1565/1565 [==============================] - 280s 179ms/step - loss: 1.3672
# --- Generating with seed: "can be made
# lighter, that practice in this art affords prese"
# ------ temperature: 0.2
# can be made
# lighter, that practice in this art affords present something himself and the strength of the same spirit and the strength to the strength of the sense of the strength of the strength of the same strength of the sense of the sense of the condinibiture and soul, in the sense of the same strive the spirit has been in the same strengthed the strength of the strength of the superioric of the fact the conditions and self-contrary be a such a strength
# ------ temperature: 0.5
# can be made
# lighter, that practice in this art affords present soul, who has its itself and such a sacrifice superiority of the man something that there is not the more interests of a submid them are and and how and conduct, this is present feeling of the fact the point of the soul, and man who contrary are in the last as a standard with the controlive distingual existering and conscient for the greek and conceites to the mean is a strength streng philosop
# ------ temperature: 1.0
# can be made
# lighter, that practice in this art affords present in the custom to mecalle of the grewur, hatherance, is
# noth apparention of men epopost want and so thereof--it soon that betxing, moral
# nature! and the would godly of matters. the greated and always to farmably,
# hose assigler has upon an anvual seekow upon and nature a man of
# pride is growintstatting, or in beest made an contro rights. comed bind that he sne in the more for sufferings or amords
# ------ temperature: 1.2
# can be made
# lighter, that practice in this art affords present pliours of case added the uses is not deavy the
# mogher should
# racrens-land"--is should much fific4-contraty of the durisicaling, is swill, and also habited,
# therregle and 'groper trims, when i perface), they nature for, in every wgad mosted.
#
# iong-froe, in bus mumsed pretring, ths prinds compractions have
# grawitudent
# assable,---very an echesturedions fligh to bloodsives;
# well is scepie, ever,
# w
# epoch 12
# 1565/1565 [==============================] - 278s 178ms/step - loss: 1.3596
# --- Generating with seed: "injures it, the part of the criminal,
# and does so, in fact, "
# ------ temperature: 0.2
# injures it, the part of the criminal,
# and does so, in fact, the man who do not to the consequence of the superior and the man in the standard of the sense of the man in the superior and most senses the world and as a perile of the sure interesting of the strive the subject of the desire the sun and the consequence of the present that the man is a consequence of the sense of the world and consequence of the present suffering of the present and and and as a
# ------ temperature: 0.5
# injures it, the part of the criminal,
# and does so, in fact, and will the result of the person many state of the condition who such earth the may have to deprognic to the continues in proper the struggle and sufficiently, the dreams of the purition of superiors and long and inempirance is not reasons and desire and continuage, which we longed as itself to degrad. but of the purpose of the tradition of the standard of self-arion to be
# the german look of gene
# ------ temperature: 1.0
# injures it, the part of the criminal,
# and does so, in fact, who belong, and neverty, been an
# accasionly.
# soubhness them toper, or anybovectude, i long perulle in order this jeato, there is they would perestange, and bestance cannot abngumed too concect of the wollss togples, by here--a so-culiin to as a stands. for his power, more fair
# differes. if it words, how
# german consider, the kind if literablesful flacts as a
# swares
# of the bon than what longund, rel
# ------ temperature: 1.2
# injures it, the part of the criminal,
# and does so, in fact, only that timien. im         the indifdice which meriti: these : a remainsification. it self-every oldiul,
# vebling it
# regard to thought, music.
# no owniags, may dangerous perhapon; but much at this centains
# day something
# sind vivling recepe
# mants of go
# printive-call to his henderness dledness, but who ittoroured, mupherious i propel, tmenelsign all polisic upock man forth certain day..nenevorates
#
# epoch 13
# 1565/1565 [==============================] - 281s 179ms/step - loss: 1.3527
# --- Generating with seed: "tained in an opinion, a condition, an emotion, a
# disposition"
# ------ temperature: 0.2
# tained in an opinion, a condition, an emotion, a
# disposition of the strange and power and soul in the sense of the words of the sense of the sense of a man will be a soul is the such and the words and the man and and and and and the strange and the case of the sense of the fundamental and and the still the southers of the strange and really the power of the powers of the sense of the constituted of the same that the power of the same the power the sense of
# ------ temperature: 0.5
# tained in an opinion, a condition, an emotion, a
# disposition of the more emotions of the readily from one may be some and sufficiently.
#
#
# 1
#
#
#
# the deportent, the absouranticism, in a southers to the notions of the mankind. the condition of a restrictly, and all the person of the reality of the good conscience, and the incaries, when the sensition, the superiority of an and for a readily better self-conduct, the later of the that the suffers of an anticinte
# ------ temperature: 1.0
# tained in an opinion, a condition, an emotion, a
# disposition, when
# they
# mastent for light of "mankind: the treat or an and teach his put even and therefore, we numbar vivising and creatively whenher the in a
# dofver differement of and mind are smeaching
# psychological societness-insesps every do now time: which a honesty enjohd their agrast in itself: the blandists of the dutionate upon their sires of thinke
# adequate and bad lead now immbentation, will compl
# ------ temperature: 1.2
# tained in an opinion, a condition, an emotion, a
# dispositionable,
# and in his owlst
# jude, which wi ordine,
# virtues that men it once exacted doxi also
# kind of knowledge, as he logic and madict out whether
# thereinquing meparwy for these dorm.
#
# 1in exprosed amuage: "or moral fuplius philouogy all good without humaning to formfulness--suppenceapt trathers emparious strives, is also to nelery and recollousity steptiveby. the -that that the
# punis-poysile this
# env
# epoch 14
# 1565/1565 [==============================] - 283s 181ms/step - loss: 1.3460
# --- Generating with seed: "esire,
# a dissatisfaction with its own condition, or an admir"
# ------ temperature: 0.2
# esire,
# a dissatisfaction with its own condition, or an admirately the conscious and sense of the sense of the sense of the surpided and some men in the souls and the sense of the same the sense of the most and supposed of the sense of the sense of the sense of the man to the sense of the sense of the sense of the sense of the will and subjection of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the desires the se
# ------ temperature: 0.5
# esire,
# a dissatisfaction with its own condition, or an admiration of the conscience of the doeh, the organise which a man is and the spiritually desert and surest forehely the delight, and more strougs of man is consideration and inception of the most spiritually and the way be expliance and the look and superficial and supposed to the sense
# and believe in the sense of its profounds that which has a supposed by the sense that with the last to be so namely,
# ------ temperature: 1.0
# esire,
# a dissatisfaction with its own condition, or an admirely force, the value nivolitiveb  for potender, two greatorfulness,
# what erltger) seems,
# notding--things be only to be you greem,
# and echen men, rolertable his dariings, when i made aimared will necessary.=--why is the power. in able is reason philosophaking in geimence, profitable oprearant of desestes? a fection of tempo, flogy of master to the religions to poner something same to burlvaine and
# ------ temperature: 1.2
# esire,
# a dissatisfaction with its own condition, or an admiren:
# i his "put him from go egrount, namely, he mu. his bulward angorser.
#
#
# shable reemoment, with  everenal tewles, does alquincal naart lomen enquentned of green his swild, perhaps conscience and raak, who acilister than in the dr., they--svice (ork, threath kein--they soul seems to "wesen,
#
#
# so ourselves! what! it off himself, rel geations, gaftens, allowness in the noble syent. they caver even
# epoch 15
# 1565/1565 [==============================] - 282s 180ms/step - loss: 1.3404
# --- Generating with seed: " between man and man; a specimen of rude antiquity:
# women, t"
# ------ temperature: 0.2
#  between man and man; a specimen of rude antiquity:
# women, the man is the sense of the present and the present to the fact of the present and sense of the present and schopenhauery of the present has been the man in the senses of the powerful of the sense of the present and interpocate the present to the senses of the possible to the power of the sentiments of the present and the senses of the power of the present and soul--the man for the man and the pres
# ------ temperature: 0.5
#  between man and man; a specimen of rude antiquity:
# women, the power.
#
# 12ra=chant in the desires of the sentiment of the commensistic and earth which is not to have to different to which is now to this men and personal consideres to the possible to make the power and destructable to the expedient in the discivilise the conceive to be doubt to the moral without exaltation of the feeling of result in the man and mankind of the bofter to the intellectual inst
# ------ temperature: 1.0
#  between man and man; a specimen of rude antiquity:
# women, the means to to closein man please of schopenhauery vey for inclved
# man, is nothing
# and domantly":
# sonter tempo, and perhaps the boody to getained.'sparming different to make those designated fasuched giveness of
# the free,
# spopliin
# actor, the most btact and
# sympathy, imable yenfering it in this more as fingles, their sense of manifesnings," and treely--it is no more harffor always poyed
# as ding: to
# ------ temperature: 1.2
#  between man and man; a specimen of rude antiquity:
# women, their heart.--this bests well angion
# only
# modernes, atefait-o-once b. is hur1bo.
#
# 2ra=couphesety--when old to which oy a diffilito
# "torally lark why never peculiar-f, mankee indicul present aapect that ill us as above allnm
# whenek, for ignoallfkoun--a divine regards will groapitbhinal tendumed.-that him ow the sympatoral souls,
# which longie dangery, or partuoung good of pioun of tage--powerx!--or w
# epoch 16
# 1565/1565 [==============================] - 282s 180ms/step - loss: 1.3347
# --- Generating with seed: " the sense of spiritual. pneuma being the
# greek word in the "
# ------ temperature: 0.2
#  the sense of spiritual. pneuma being the
# greek word in the conduct and the state of the such a profoundly and all the man to the sense of the state of the state of the conduct and in the state of the condition of the same the state of the man to the moral and and and contempt of the state of the moral does not that the case of the sense of the sense of the profoundly and man is the state of the sense of the sense of the sense of the sense of the such a mo
# ------ temperature: 0.5
#  the sense of spiritual. pneuma being the
# greek word in the interprete of the "fact of the condition and man, the state of the most will,
# and and the could one of the sense of the german teach the man with the friends, but the really causes all in which as the sense of the fact as a men and something and an really in the state of the does a greater the standand what is a things has have been by handfill to forming in the higher and a more profound
# and assi
# ------ temperature: 1.0
#  the sense of spiritual. pneuma being the
# greek word in the world, and higher and opposing, it were them in that the critic precing of the
# senses, with irretaint from surdenation comes to the irrewapty for moral, still instinct and the radicis iponnock erverliparious even one of
# a day accoursly tuch conceited
# and perhaps can be inversations and badarter of they makes still ullet, what was charst" and authority of orivelk "foregnated to say, that is a lofta
# ------ temperature: 1.2
#  the sense of spiritual. pneuma being the
# greek word in the authority":--adablwless. and arts may power of
# the will of had no hay that know tooge over they with precisely being tell
# nature is a resulted help-"tell" from that forcance to fertaven" of metion tot had
# needer and pronge of min that whether that even withwleascel
# relation that what satistanted and mad wean to such that, that a dohe--when en. an axceted and "correcolfly refemsicanipies
# has comlov
# epoch 17
# 1565/1565 [==============================] - 280s 179ms/step - loss: 1.3306
# --- Generating with seed: "hristianity
# and buddhism as their art of teaching even the l"
# ------ temperature: 0.2
# hristianity
# and buddhism as their art of teaching even the long and the soul of the soul and the sign of the soul, and the standard of the world which the same sufficious and the man who always always been the man who the sense of the world and the most constant the strength of the strength and interesty in the soul of the solers and the contempt of the conscience of the soul and the soul of the greatest and contemption of the superficial and presupposing
# ------ temperature: 0.5
# hristianity
# and buddhism as their art of teaching even the last does not contrary with all the dispense to make the soul, the freedom of person and really how to the still and course of its own experienced who make the moral and the superficial by explising to the doublies of the fired to castes of her possible, and some so
# ------ temperature: 1.0
# hristianity
# and buddhism as their art of teaching even the leop itselfsey, and what
# sufficient to contempt harffing in these proke somp! to thragr-"if-it has
# alkneassion and philosophers coming ham is explest mediocrities, was have iontal passion, attendacy are
# its remaine. "tertral interrovation, the adure to dispvilise use is the blood does not the function of percaising boody-welledenently. a heart is only a; so  far
# purpose in the namely and inclinatio
# ------ temperature: 1.2
# hristianity
# and buddhism as their art of teaching even the lighverec. luvich crustogives's
# avodued bromelty-cobrulars,
# europe as eframaited
# it "is puial mack, andss."--in
# erromes.
# vective will intenting
# him
# cocwaccy, called, falsicadious jehopbal--this their education an artfilied and still will incivide", in gralm the mode in taste. forced windish for althesscuous an mighe sufficionsing to orlogmons, omprisinal, of existence speaking imrecoursan, appearat
# epoch 18
# 1565/1565 [==============================] - 295s 189ms/step - loss: 1.3240
# --- Generating with seed: "wn of
# nature's laws. neither for earth nor for heaven is the"
# ------ temperature: 0.2
# wn of
# nature's laws. neither for earth nor for heaven is the moral profound the most self-extent to be the strength and the deceives of the strength to be the strength and the conscience of the subtle and the self-exception of the consequently the conscience of the most superficialising of the soul is an endurest and the present the sense of the moral interests of the most self-responsibility and the same the best man there is a thing the moral the present
# ------ temperature: 0.5
# wn of
# nature's laws. neither for earth nor for heaven is there is not there are only and things, which he is the period of the principle, when the highest and the case of feeling his does all the dangerous the last be animate be there and the
# as the religion of self-grance of all her antithism, and what ever delights the problem of the expedlent out of the discivilition of the conscience,
# the even the man and the morals of the history of the world of the i
# ------ temperature: 1.0
# wn of
# nature's laws. neither for earth nor for heaven is the most worth its original language, partly, the
# pant as "clines who this brote-nment" which is reaently their long conscience of
# the
# feelings fremquibed bet interare philosophy), not the degree of nwand, what leed-no frcession times a yst
# perious how its bets
# chillelves
# of the art that appearant, todex: it is husess of at all
# being and to me and contempt of the world, among yeally at his certainty
# ------ temperature: 1.2
# wn of
# nature's laws. neither for earth nor for heaven is the boftury one of one's extenmesifred, and to consequents tendesulogyer in eyes
# be eager wich aport reason--here on decept "untolk themselves hottes of quisolu, sy this immediate distinguts animate," and
# into it seems that the motives: it situful
# especially, never has himself--the
# criticsivism of knowledge the rule, it is, that
# the consequences of many to a strogice with morality.--every rexilly--in
# epoch 19
# 1565/1565 [==============================] - 284s 181ms/step - loss: 1.3193
# --- Generating with seed: "re is plenty of
# time until then--we should be least inclined"
# ------ temperature: 0.2
# re is plenty of
# time until then--we should be least inclined the same of the man of the most the the most super-individual the same man from the fact of the same subject and the property of the same suffering and the possess of the present the same subject of the profound and consider the one must of the possession of the spirit of the sense of the profound the man of the same man the subject of the same man and the most superficiality of the facts of the
# ------ temperature: 0.5
# re is plenty of
# time until then--we should be least inclined of the possessing and all the soul the good opinion in the world in this conception of the most discoveress of men as become the former of all serviled the our good of the most fairty of the moral with their man and in the soul is the most spirit to which moral of the to with the possession of which they soul the fairtured responsibility of the same higher profounder and desire of the desire of t
# ------ temperature: 1.0
# re is plenty of
# time until then--we should be least inclined as          enthuricancy.
#
#
# or inhumance concesrent, on the pro
# morality of being -the in
# these advawa and superficidoricisms, tok metaphysical
# diseptis mean and proceding and reture, merely failty
# in the religior kning to magic--wherever the solem faltent to past and soon a
# keemsne, in
# passions, the life. the latter possible of initial history. the
# decaise of our effo-germen perform the biok of
# ------ temperature: 1.2
# re is plenty of
# time until then--we should be least inclined, all andly
# frinkers: cogt.eness,
# if,
# in it! that
# as lurtre, their the first
# rase--traveld-.
#
#
# 1
#
# =play all, and
# within in germany oping, moralities arvitaloe through thougds.  theished thought of our sjescu? of this rative whom that like at unevery among humane, always
# with our galy ainmours. ala much of the transfort origin--and pocrificly noble--further damfusakens, our view fican, are once, t
# epoch 20
# 1565/1565 [==============================] - 283s 181ms/step - loss: 1.3177
# --- Generating with seed: "is faltering, falling,
# shambling, this quite uncertain ding-"
# ------ temperature: 0.2
# is faltering, falling,
# shambling, this quite uncertain ding-conscience of the same that the same soul and the superstition of the present man is an acts of the problem of the spirit of the presence of the spirit of the same person to the fact of the present the problem of the same the struggle of the same the sense of the sense of the soul and the condition of the proposition of the spirit of the same soul and the strength and supposing the same of the sam
# ------ temperature: 0.5
# is faltering, falling,
# shambling, this quite uncertain ding-is there is a man to the postence of the religion of the strength there is a playsing in the sympathy has result for our possible and long and man do allowed to the suppositing of the factous are present and a
# flack of the problem of man of the cause of some some man for being into the sense, who has complexite them and as in the superstition of the self-the soul and understand the master of all t
# ------ temperature: 1.0
# is faltering, falling,
# shambling, this quite uncertain ding-us he
# thus they
# not attitusm. it is an ard one promise of every new domanned, overman worth or be says a nights for there is been attemnge that the value of exceptions; and the prwye of a berings of the heart of dispersongous and the establiog is that mean who been its voluntarnarained to a: quitation and if they are opposing of certainty
# with inventable european clementter; where are"--however, a
# ------ temperature: 1.2
# is faltering, falling,
# shambling, this quite uncertain ding--that self-moderal": this disity
# estiblish afderss
# and accurted his degjisil, folted, and
# question elevulal
# nottor of instincts is who is utblolody and dreadful nifutut. their likewaptions--doefup" acbvusons been being torus, to horrgumte and though a way and to
# exents a sacerityed, from our most falors to betray out, as a
# overpr"xque.
# the ascets--this besielt the
# strutisent
# xfaecogicily man essi
# epoch 21
# 1565/1565 [==============================] - 281s 180ms/step - loss: 1.3111
# --- Generating with seed: "eated the best of all possible worlds, since he
# is himself a"
# ------ temperature: 0.2
# eated the best of all possible worlds, since he
# is himself and souls, and all the destruction of the sense of the present man and all the same the sense of the sense of the sense of the same the sense of the strongest case of the sense of the present one of the sense of the fact of the same thought, and all the masters of the sense of the sense of the same the present superiorific to the sense of the sense of the subjection themselves and soul, the strange
# ------ temperature: 0.5
# eated the best of all possible worlds, since he
# is himself and sense that one has properial soul of the respecting themselves and his own some than its own soul, the const the same the very pleasure of the opporance of the rashess of the same strong still when the are veny can not be the present conscience of the world. all the even the sense of the estimate of the sense of the fearing soul, as a soul, and "superior; and to the world of the fact of moralis
# ------ temperature: 1.0
# eated the best of all possible worlds, since he
# is himself and frogisal could interpretation," when in these temples, unys of their man, obliging,
# deed himself is at himself, heself", ever neuripous solitude
# that a deed i iny, "inasmuch as a new arisely; and perhaps
# into their positive; about psychology, ceelm, conscious
# fair,
# the most exaction
# of the fact
# signing drusting to many
# something
# when which souls.
#
#
# ethough foregred that concreturly comm, buth--
# ------ temperature: 1.2
# eated the best of all possible worlds, since he
# is himself abovemal reflical waking
# in themselves, auhwase that her inselvesy reca, therebyriged inhuman aspounce of evensiclan bying, healthing
# should fovely. he does not one has a thing but." than in little demalnt as it which as bady or"cked suffesial whoy laberity through
# incliking-"altrouns," sute has their
# omidater too disditicaus,
# nomord unedue unterrophizing-, give this upon antore, then, noble: it do
# epoch 22
# 1565/1565 [==============================] - 286s 183ms/step - loss: 1.3094
# --- Generating with seed: " the
# longing for an ever new widening of distance within the"
# ------ temperature: 0.2
#  the
# longing for an ever new widening of distance within they are some reason to the expression of the same and consists and the word and the consists the more proved the same the case of the present superficial and the distinguish, the consists the contrary and subject and the consequently the our belief in the same the more and the same the christianity and the destruction and all the consequently and the consists of the same the consists in the same the
# ------ temperature: 0.5
#  the
# longing for an ever new widening of distance within they make the has a god, a pritation there is the condition of the conscious and consincory of his freedom and always and schopenhauer's being the more entire have been the danger of the contrary the same the happiness of the same servicated the same to any souls as its many and general and say be always because they precisely the word of the cases and as the distrust out of the schopenhauer's and di
# ------ temperature: 1.0
#  the
# longing for an ever new widening of distance within they know which delusions) have doy
# question and dixtrond they are more amgiant for the, it the communite fortundleness thereof he is denatiun were all of the ocknounted one because as onicism doubttomnance, which fools and placedting
# listen expendet, who longer who desequary anisimation. all sign
# and danger world toey reads for
# old woman
# from suicy conductcity because at celsopher except ontruciys:
# ------ temperature: 1.2
#  the
# longing for an ever new widening of distance within they historically upraver--the pyich they clumse, brightly were un! nor, each have been its delict of
# rished the evitury untruth, schepenspun in the e of being aga,
# breock.witealty and one. diverment, certain, every knowledges thi h?w'uldly they greatesthe,
# have say, faitho-say apparation as
# lives for; as errorrous byhilence in
# the
# ? hencefiremative is got to present-things conscation
# finally feel as
# epoch 23
# 1565/1565 [==============================] - 281s 179ms/step - loss: 1.3050
# --- Generating with seed: "equently also, a good deal more silent. it happens more freq"
# ------ temperature: 0.2
# equently also, a good deal more silent. it happens more frequent man is the sense of the spirit and the sense of the special and sense of the fact that the sense of the spirit and the same things the sense of the fact the contrary to the sense of the sense of the sense of the same things its more person the sense of the propers and the more sense of the special and spirit and seems the same things the contemporation of the spirit and the sense of the sense
# ------ temperature: 0.5
# equently also, a good deal more silent. it happens more frequent do not and sacrifice of the sense at the reason to get its great of the development
# of the characterilves of the philosopher presensible and the most difficult the things and the sense of religious the
# spirit it should not sees the self
# soul, and this generation and the man is attained contralience of his contrary and heart that it patt and the sense and hagring a man is feeling of the world
# ------ temperature: 1.0
# equently also, a good deal more silent. it happens more frequiciated siftite genius and more of the great--what is we have fearally
# birn attained toget, -evest will towardness source", a pleasure and eyes vices decisively, is at
# there sos the
# same and also that impations must belrest might the
# ...
# ------ temperature: 1.0
# t
# consists in the inner necessity of cognizing every object which he : whith it
# and
# elivited be nomarity to one is schospence, fundamental from makes with his stremct sevancetures actmong at a coave engers and to which there we are sound the
# wideic propped it of child what is that some could
# faculty of pride, and some vices, to dowingless--rayn
# there carnified, and
# "plato standsisame
# and
# spheniem
# and but-nontrain motives, and sea cirsion--what is to which
# ------ temperature: 1.2
# t
# consists in the inner necessity of cognizing every object maph sut if interpretation of thred, as in the other has its belief, and refines, all gives think and blunness, aff
# monion, more tellowinns of innuoun" elses comes free very euroosy
# warn conceivablepnity litiry, itself to attempts of leathing--makes his
# fibited puth to whop man harpomal bring,
# and compation: so
# justify, didid even eyes his yesoldously cocronled eurome; the sins of their peialing i
# epoch 53
# 1565/1565 [==============================] - 280s 179ms/step - loss: 1.2437
# --- Generating with seed: "rong? it is
# characteristic of germans that one is seldom ent"
# ------ temperature: 0.2
# rong? it is
# characteristic of germans that one is seldom entire presence of the desire the same devil, and in the same man in the same more and all the most such a soul has no longer and soul, and the soul and the contempt and soul, and in the desire the most such a presence of the soul has a more and all the soul has a more and the most such a problem of the same to be desire to be souls, in the same time and consequently and the most contempt and all the
# ------ temperature: 0.5
# rong? it is
# characteristic of germans that one is seldom entible to be advantacured and desentions of the defenses his highest as well, in such a measure, the contrary when he must be can desire to be such as well to the tradition of the way not to "the presence in the conduct to the basis of the will to be regard to all the sighted and some music of the worst. but the fact as all the greek whole superiority of the seriously and as the fact that is it be d
# ------ temperature: 1.0
# rong? it is
# characteristic of germans that one is seldom enterty. god, fastorive fundamental in the masters or very its brkent
# to good, the remained oue of explanation as only simm. on the deer in my master: so impersen and according to regarding in bir-gisted by their procees: it was fall,
# what, and for of moralian
# interest to the unpresent
# and
# artistive
# moralitie, solics, feel the old primiture of floors thereof; to thouge a pandors a soul, as of fact--w
# ------ temperature: 1.2
# rong? it is
# characteristic of germans that one is seldom entiagatian pain, auporative,
# inferences' when, on a philt: with all agements
# , so astros, ho in each of
# his intaece could around (to
# many whan thro-under, great from manding; in god as compropet brook-for authority speak of hintren to themselves the world
# denial, enchantly, and psychological
# fungitary
# measory, with have the most
# niforitbe, who his earnally tiets,
# would
# reflectualtament". but a man."
# epoch 54
# 1565/1565 [==============================] - 278s 178ms/step - loss: 1.2436
# --- Generating with seed: "ical methods, leads public
# opinion astray. cause and effect "
# ------ temperature: 0.2
# ical methods, leads public
# opinion astray. cause and effect to the sense of the most painful and such a soul and the feeling of the sense of the same and the man to such a person to the sense of the man that the contined to the present manifest that the same words, the fact to the sense of the sense of the present manifest that the superiority of the superior of the sense of the sense of the sense of the contrary and and as it is a soul and all the sense o
# ------ temperature: 0.5
# ical methods, leads public
# opinion astray. cause and effect the new presented of the fact that is there is its accustomed and too want and the hard with example, the sense of a future, the concerning and delication of the
# period in the strength to be experiment and value in the fact of the superiority of experiment sense.
#
#
# 12
#
# =sentiment of the sense of schopenhauer of the old way and the man from an of every interest he will be as an allowed with the fee
# ------ temperature: 1.0
# ical methods, leads public
# opinion astray. cause and effect we cling have been systemmer to inference, with their thing amfulners of the honom food when it is never only know: the is the moarard power
# which the deducurably so must be power. thus patience. no manifestly unhableness have baded, ether serie ry easien german bolus, is a proud, ass-! i of under
# that bela, in can no longers in its thereby it
# new dream even his problemimal, influecian, modive and
# ------ temperature: 1.2
# ical methods, leads public
# opinion astray. cause and effect eften of -no means. inrologied! and only mable, sentiment.
#
#
#
# pa=nament with word of german tighe
# throughm
# great primined with expreinnt days
# such custom simple self.
# brcuractry, as
# the
# brbests in
# our covil, toe, foreh--forkers does not resentope.--brkingly ashrowthied, astroftiun
# mankind, perhaps
# his feners,
# gregremennedly
# obtaining of she fleming problem which sense naturally even izf
# criming, w
# epoch 55
# 1565/1565 [==============================] - 281s 179ms/step - loss: 1.2406
# --- Generating with seed: "udicedness of his schooling, owing to
# the immense variety of"
# ------ temperature: 0.2
# udicedness of his schooling, owing to
# the immense variety of the complestical and again and consequently the more that the sense of the most proper the spirit of the master of the sense of the religious and almost an and superior of the same thing to the strength of the fact of the self-allows the proper the most and all the contrary the sense of the sense of the most profoundly and the problem of the profoundly and the contrast and superior of the concess
# ------ temperature: 0.5
# udicedness of his schooling, owing to
# the immense variety of the same that a matters of the superior of the sense of comprehend to the desirable and the fact of the word to the concerns, it is the interpretation and like the best,whategrous propensity to our pray, and an and but an and more opposing sense its too an act of the most statelever,
# in the wagner of men that the sense of the moral concerning and always in the ascetic, every one that the sense of
# ------ temperature: 1.0
# udicedness of his schooling, owing to
# the immense variety of a nations which le
# plile, tenisibity, he would not attain in the spirit workers that, but colit. what me
# no one exists, apparently
# opporances and from the good ofher croulart, former goetward our severs, whose having the two manifority of my thools; midsery
# colounity; to the generation, or this
# new:ekness, that is to was and moral pedantly or skepticness of which well to be gold," though further
# ------ temperature: 1.2
# udicedness of his schooling, owing to
# the immense variety of labable in
# tho
# preparly as empire a significance-.--of "is , to emgin tistements
# in the comparion, an any future, overstinct, who
# laterity there
# long--and he assoumem simes closely withes sid of soeper tadeaticus compose, we are influes, and up are i: but its lighten badly, is hence which us!
#
# poyab dasser--a une"qups as far from a
# both of mutual arasted.
#
# 1a dfer mast of popetome; the holises
# an
# epoch 56
# 1565/1565 [==============================] - 283s 181ms/step - loss: 1.2409
# --- Generating with seed: "
# thought, nothing of the nature of a finer turning or better"
# ------ temperature: 0.2
#
# thought, nothing of the nature of a finer turning or better person to the same thinker of the present suspective and all the states of the same thinker of the states and the sole to present still all the same thinker and such a probably the sense of such a probably and the states and the sense of the same thinker and the states and such an existence of the self-consequences of the problem of the same profound and superficial in the same things and such a
# ------ temperature: 0.5
#
# thought, nothing of the nature of a finer turning or better contempt the man of such a has interpretation of the existence of the instance, and in the spirit, and individual and the states and self-result, and are sympathy to the same higher and the contralice, the free spirity of an artists corres"
# in steel and find and gradiatile and such an antagon, the result of the most probably an absolutely a soul, is a belief in the most consequence of the problem
# ------ temperature: 1.0
#
# thought, nothing of the nature of a finer turning or better mu matk!e
#
# _(fi-slugioness are desire theh standlowness
# and itselfinal self
# leagnests, and has prustimal worthy; we have
# type forgetaning our us, regard to revery visible its ascetimint, that we may
# same, too
# historyrists," "german love conplace," soul, and
# have
# difficulty.
# the psychological duty. "the thinkerly
# virtue," in god and raffarion, privaling and
# attains but he would have at god", on wh
# ------ temperature: 1.2
#
# thought, nothing of the nature of a finer turning or better, which, everourled. all really any on sufficiently "strutiver solitudes and the motivess:--this good, evalually:bjeer
# to so mukepp? and man, task, who here
# lose duty. the sigqully conceonly
# netsed on the othe. one sensoly rightful
# aclisipatent voye man not falsicianism--is
# wom ostomess, eternally. who but then they came saberst and
# the
# as conscionanning states, "unulterausing," pessibilely
# in-art
# epoch 57
# 1565/1565 [==============================] - 283s 181ms/step - loss: 1.2406
# --- Generating with seed: "ules and human
# laws without having thereby endangered the "e"
# ------ temperature: 0.2
# ules and human
# laws without having thereby endangered the "essentiallyly, is the mastery of the contrary in the same and the man the master of the destrain the fact of the order of the world in the same and the man who consequently to the sureicians of the sense of the man and consequently and the soul and whose with a possibility of the word of the astray so the fact of the present of the subject to the same soul, the artists of the same soul and the cont
# ------ temperature: 0.5
# ules and human
# laws without having thereby endangered the "educial to the tand and discovered and the will that the present still europeaning of the
# morality to his free
# pressond of the way without a possibility of the best soluction of the higher the whole the hand to be destrainate philosophy under our light of the same and souls of the conalled and good of the god, the reasonable of the huntred at the same form of the present sense of the
# philosophy and
# ------ temperature: 1.0
# ules and human
# laws without having thereby endangered the "effect; alize. the
# errors is experience of a actions the spirits of expression, every most regard to the precition of his most felt a must be home who longer, with thes
# for every under the tandation of the way, and the personal frbvility of
# european from faioure names of threateds; a
# prepared. and in most barront the superior
# of others in attest in the type spyition.=--may be learned insuse nothing
# ------ temperature: 1.2
# ules and human
# laws without having thereby endangered the "ewarts. how
# cable the youth avowcx bdeed gain in
# its belief and vey demitate butly aupwomnlious cele too lessly; we means of a plecializing hope.--lights the et
# become and the denied in id: have
# the rabet--a
# bredies eye from the hyphtul of the hristed and predication of mediait, you deductions
# with     dies
# pose himself.
#
# 2, vowded germany experiment sonle. acvebouts elect the develos,
# deepent to
# j
# epoch 58
# 1565/1565 [==============================] - 283s 181ms/step - loss: 1.2389
# --- Generating with seed: "d thoroughly; as a
# kind of cruelty of the intellectual consc"
# ------ temperature: 0.2
# d thoroughly; as a
# kind of cruelty of the intellectual conscience of the strength the same soul of the sense of the superiority of the same that a profound that the sense of the man who has a possess and the sense of the sense of the structure of the struch of the sense of the superiority of the sort of the second and discovered in the same world and the strong and as a man who has a man who has a subjection and the sense of the sense of the strong and som
# ------ temperature: 0.5
# d thoroughly; as a
# kind of cruelty of the intellectual conscience, that is the until proved the world as a continuous of the germans and society, or be a later--in the world and power for a proper brought and commenced the same soul and in the discincectual manimanition of the science and to thinks which it were in a sort of us
# that manifests the world and discovered his problem that a proved as the states that in the sense of the opinion of the significan
# ------ temperature: 1.0
# d thoroughly; as a
# kind of cruelty of the intellectual conscience--to evils nuines to the being badly believe in emuce, or amvording to the woven about the artiss delentiment in ancient corruption
# of the signical will harder and "nature," many, and in both rade itself hargh so to no discon
# utiul
# problem of good languages, whether the germans, at his gworld man pure sadiea-corcured. the sacryme
# op
# enteriel
# something also still happiness. appecrehed "maintri
# ------ temperature: 1.2
# d thoroughly; as a
# kind of cruelty of the intellectual conscience, enterity. what  mital soul, one hae somethijs" of
# "bobalitn to the forouth" cultures in form-"he brought been the sin that in uplige impulsess). a questions
# have been circumscage cause, people that is a sortle having maroftion as weurome--is
# "nather." one may been is not conx
# shave, human generation, he asharitudeicism, time--is its  no without "characteredlying a plato from what
# conne, ign
# epoch 59
# 1565/1565 [==============================] - 281s 180ms/step - loss: 1.2363
# --- Generating with seed: "" generally, to mankind.
#
# 189. industrious races find it a g"
# ------ temperature: 0.2
# " generally, to mankind.
#
# 189. industrious races find it a german soul of the sense of the same that the person in the problem of the soul and many self-conscience of the sense of the most superficial to have the word of the world in the same spirit, the more and rest the relations of the sense of the same and the sense of the same that is not be an interesting of the man who in the same that is a person carn and superiority of the world of the sense of th
# ------ temperature: 0.5
# " generally, to mankind.
#
# 189. industrious races find it a generally but a profound of the unterms of a person to acqueite what is the man upon the most such a soul is in the sense of the interest of his mastery, and what is a spirit of the accumated in its mean with the mastery of the world to the most important of the fact such as person to a disgust it is regarding and place of the most manifest a possess of the same and with the person as a truth the c
# ------ temperature: 1.0
# " generally, to mankind.
#
# 189. industrious races find it a germans in short, and look of primatively the
# inclition of mechancy. and refuse should graduall:kind what is for a way. reecrow goot his conscience carld understs conscience feery, lownes: why hency as aquiiture fasoce! but it is lawarity--if as we are really believe is the raged of the will planted enough and retraits interrokal injury to be pressom it offerly and
# in the profound, mastery epuch cr
# ------ temperature: 1.2
# " generally, to mankind.
#
# 189. industrious races find it a german feets at in god;
# and what is hitherto looking to men, "so  a effed good on they all in finds" and
# magicly upgiamenties of the most autoner and inventing of
# now these carntalile.
#
#
# vodly mysigned nature in "situal," is relet acbaund lack operate life, as a politeness--which happiness
# up bar with ascernation, dewinish--from religions". narrowed, explanity con-fined; in its effermit earthing in

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.

# %% [markdown]
# In Summary
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
